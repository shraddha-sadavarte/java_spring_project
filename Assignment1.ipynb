# %%
# !pip install numpy

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.5 MB 4.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.5 MB 4.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/11.5 MB 5.0 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.5 MB 5.3 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.5 MB 5.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.8/11.5 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.5 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 5.8 MB/s eta 0:00:00
# ...

# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.0 MB 4.0 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.0 MB 4.8 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.0 MB 4.8 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.0 MB 5.1 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 5.1 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 5.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 4.2 MB/s eta 0:00:00
# ...

# %%
pip install -U scikit-learn
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 5.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.1 MB 4.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/11.1 MB 4.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/11.1 MB 3.9 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/11.1 MB 3.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.7/11.1 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.1 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.1 MB 3.9 MB/s eta 0:00:02
#    -------------------------- ------------- 7.3/11.1 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.1 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.1 MB 4.1 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
url='http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
column_names=['sepal_length','sepal_width','petal_length','petal_width','target']
df = pd.read_csv(url,header=None,names=column_names)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          target
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width       target
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          target
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.size
# Out:
# 750

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0           False        False         False        False   False
# 1           False        False         False        False   False
# 2           False        False         False        False   False
# 3           False        False         False        False   False
# 4           False        False         False        False   False
# ..            ...          ...           ...          ...     ...
# 145         False        False         False        False   False
# 146         False        False         False        False   False
# 147         False        False         False        False   False
# 148         False        False         False        False   False
# 149         False        False         False        False   False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# target          0
# dtype: int64

# %%
df.loc[5,'sepal_length']=np.nan

# %%
df.isnull().sum()
# Out:
# sepal_length    1
# sepal_width     0
# petal_length    0
# petal_width     0
# target          0
# dtype: int64

# %%
df.loc[4,'sepal_width']=np.nan
df.loc[3,'petal_length']=np.nan
df.loc[2,'petal_width']=np.nan
df.loc[5,'target']=np.nan

# %%
df.isnull().sum()
# Out:
# sepal_length    1
# sepal_width     1
# petal_length    1
# petal_width     1
# target          1
# dtype: int64

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0           False        False         False        False   False
# 1           False        False         False        False   False
# 2           False        False         False         True   False
# 3           False        False          True        False   False
# 4           False         True         False        False   False
# ..            ...          ...           ...          ...     ...
# 145         False        False         False        False   False
# 146         False        False         False        False   False
# 147         False        False         False        False   False
# 148         False        False         False        False   False
# 149         False        False         False        False   False
#
# [150 rows x 5 columns]

# %%
df_miss_drop=df.copy()

# %%
v1=df_miss_drop.dropna()

# %%
df_miss_drop=df.copy()

# %%
df_miss_drop.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          target
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0           False        False         False        False   False
# 1           False        False         False        False   False
# 2           False        False         False         True   False
# 3           False        False          True        False   False
# 4           False         True         False        False   False
# ..            ...          ...           ...          ...     ...
# 145         False        False         False        False   False
# 146         False        False         False        False   False
# 147         False        False         False        False   False
# 148         False        False         False        False   False
# 149         False        False         False        False   False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    1
# sepal_width     1
# petal_length    1
# petal_width     1
# target          1
# dtype: int64

# %%
v1=df_miss_drop.dropna()

# %%
print(v1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          target
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]

# %%
v1.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# target          0
# dtype: int64

# %%
df_mean_sl=df.copy()

# %%
df_mean_sl=df_mean_sl.fillna(df_mean_sl['sepal_length'].mean)

# %%
df_mean_sl
# Out:
#     sepal_length                                        sepal_width  \
# 0            5.1                                                3.5
# 1            4.9                                                3.0
# 2            4.7                                                3.2
# 3            4.6                                                3.1
# 4            5.0  <bound method Series.mean of 0      5.1\n1    ...
# ..           ...                                                ...
# 145          6.7                                                3.0
# 146          6.3                                                2.5
# 147          6.5                                                3.0
# 148          6.2                                                3.4
# 149          5.9                                                3.0
#
#                                           petal_length  \
# 0                                                  1.4
# ...

# %%
v2=df_mean_sl.isnull()

# %%
v2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0           False        False         False        False   False
# 1           False        False         False        False   False
# 2           False        False         False        False   False
# 3           False        False         False        False   False
# 4           False        False         False        False   False
# ..            ...          ...           ...          ...     ...
# 145         False        False         False        False   False
# 146         False        False         False        False   False
# 147         False        False         False        False   False
# 148         False        False         False        False   False
# 149         False        False         False        False   False
#
# [150 rows x 5 columns]

# %%
v3=df_mean_sl.isnull().sum()

# %%
v3
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# target          0
# dtype: int64

# %%
df_fd=df.copy()

# %%
df_fd=df_fd.fillna(method='ffill')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10344\2844962574.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_fd=df_fd.fillna(method='ffill')

# %%
v4=df_fd.isnull()

# %%
v4
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0           False        False         False        False   False
# 1           False        False         False        False   False
# 2           False        False         False        False   False
# 3           False        False         False        False   False
# 4           False        False         False        False   False
# ..            ...          ...           ...          ...     ...
# 145         False        False         False        False   False
# 146         False        False         False        False   False
# 147         False        False         False        False   False
# 148         False        False         False        False   False
# 149         False        False         False        False   False
#
# [150 rows x 5 columns]

# %%
v5=df_fd.isnull().sum()

# %%
v5
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# target          0
# dtype: int64

# %%
df_bd=df.copy()

# %%
df_bd=df_bd.fillna(method='bfill')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10344\654438956.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bd=df_bd.fillna(method='bfill')

# %%
v6=df_bd.isnull().sum()

# %%
v6
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# target          0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
numeric_val=['sepal_length','sepal_width','petal_length','petal_width']

# %%
scaler=MinMaxScaler()

# %%
df[numeric_val]=scaler.fit_transform(df[numeric_val])

# %%
df[numeric_val]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0        0.222222     0.625000      0.067797     0.041667
# 1        0.166667     0.416667      0.067797     0.041667
# 2        0.111111     0.500000      0.050847          NaN
# 3        0.083333     0.458333           NaN     0.041667
# 4        0.194444          NaN      0.067797     0.041667
# ..            ...          ...           ...          ...
# 145      0.666667     0.416667      0.711864     0.916667
# 146      0.555556     0.208333      0.677966     0.750000
# 147      0.611111     0.416667      0.711864     0.791667
# 148      0.527778     0.583333      0.745763     0.916667
# 149      0.444444     0.416667      0.694915     0.708333
#
# [150 rows x 4 columns]

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width       target
# 0      0.222222     0.625000      0.067797     0.041667  Iris-setosa
# 1      0.166667     0.416667      0.067797     0.041667  Iris-setosa

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# target           object
# dtype: object

# %%
cate
